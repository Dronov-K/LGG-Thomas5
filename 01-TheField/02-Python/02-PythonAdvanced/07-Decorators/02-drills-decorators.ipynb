# %% [markdown]
# # Drill - Decorators
#
# ### Exercise 1
# Create a decorator that limits the execution of a function:
#
# When the function is executed too many times, an exception is thrown. The decorator must take one parameter, which is the number of times it is executed.

# %%
from functools import wraps


def limit_of_execution(limit: int):
  def real_decorator(func):
    count_of_limit = 0

    @wraps(func)
    def wrapper(*args, **kwargs):
      nonlocal count_of_limit

      if count_of_limit >= limit:
        raise RuntimeError(f'{func.__name__} is over the limit of calls')
      count_of_limit += 1
      return func(*args, **kwargs)

    return wrapper
  return real_decorator


@limit_of_execution(2)
def greet():
  print('Hello, everyone')


if __name__ == '__main__':
  greet()
  greet()
  greet()
# Out:
# Hello, everyone
# Hello, everyone
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-de86acc36bf6> in <cell line: 0>()
#      27   greet()
#      28   greet()
# ---> 29   greet()
#
# <ipython-input-3-de86acc36bf6> in wrapper(*args, **kwargs)
#      11
#      12       if count_of_limit >= limit:
# ---> 13         raise RuntimeError(f'{func.__name__} is over the limit of calls')
#      14       count_of_limit += 1
#      15       return func(*args, **kwargs)
#
# RuntimeError: greet is over the limit of calls

# %% [markdown]
# ### Exercise 2
# Create a decorator that controls what a function returns. The decorator must throw an exception if the function returns a string or an int.

# %%
from functools import wraps


def control_of_returns(func):
    @wraps(func)
    def wrapper(*args, **kwargs):
        result = func(*args, **kwargs)
        if isinstance(result, int | str):
            raise TypeError(f"{func.__name__} can't return integers and strings")
        return result

    return wrapper


@control_of_returns
def get_sum(a, b):
    return a + b


if __name__ == '__main__':
    print(get_sum([1, 2, 3], [4, 5, 6, 7]))
    print(get_sum(5.6, 3.2))
    print(get_sum(5.6, 3))
    print(get_sum(5, 3))
    print(get_sum('a', 'b'))
    print(get_sum(True, True))
# Out:
# [1, 2, 3, 4, 5, 6, 7]
# 8.8
# 8.6
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-60f395ce79b1> in <cell line: 0>()
#      22     print(get_sum(5.6, 3.2))
#      23     print(get_sum(5.6, 3))
# ---> 24     print(get_sum(5, 3))
#      25     print(get_sum('a', 'b'))
#      26     print(get_sum(True, True))
#
# <ipython-input-5-60f395ce79b1> in wrapper(*args, **kwargs)
#       7         result = func(*args, **kwargs)
#       8         if isinstance(result, int | str):
# ----> 9             raise TypeError(f"{func.__name__} can't return integers and strings")
#      10         return result
#      11
#
# TypeError: get_sum can't return integers and strings

# %% [markdown]
# ### Exercise 3
# A decorator that displays the time it took for the function to run (basic).

# %%
import time
from functools import wraps


def get_func_work_time(func):
    @wraps(func)
    def wrapper(*args, **kwargs):
        start_time = time.time()
        result = func(*args, **kwargs)
        end_time = time.time()
        func_work_time = end_time - start_time

        return f'Work time for {func.__name__} function is {func_work_time:.7f} sec, result = {result}'

    return wrapper


@get_func_work_time
def get_nod(a, b):
    """Slow Euclidean algorithm """

    while a != b:
        if a > b:
            a -= b
        else:
            b -= a
    return a


@get_func_work_time
def get_fast_nod(a, b):
    """Fast Euclidean algorithm"""

    while b > 0:
        a, b = b, a % b
    return a


if __name__ == '__main__':
    print(get_nod.__doc__, get_nod(2, 10_000_000), sep='\n')
    print()
    print(get_fast_nod.__doc__, get_fast_nod(2, 10_000_000), sep='\n')
# Out:
# Slow Euclidean algorithm
# Work time for get_nod function is 0.8173313 sec, result = 2
#
# Fast Euclidean algorithm
# Work time for get_fast_nod function is 0.0000024 sec, result = 2
