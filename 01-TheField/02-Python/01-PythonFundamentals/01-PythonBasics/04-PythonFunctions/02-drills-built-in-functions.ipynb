# %% [markdown]
# # Drill : built-in functions
# Use the native python functions to do these exercises.

# %% [markdown]
# ### 1. Create a variable `count_alpha` that contains the number of characters contained in the string `"Hello world!"`.

# %%
count_alpha = len("Hello world!")

# %% [markdown]
# ### 2. Create a variable `count_float` and cast the variable `count_alpha` to float.

# %%
count_float = float(count_alpha)

# %% [markdown]
# ### 3. Round the variable `pi` value to 2 decimal places (0.01) and save it in a variable `round_pi`. You can get `pi` from the `math` library.

# %%
import math

round_pi = round(math.pi, 2)

# %% [markdown]
# ### 4. Create a variable `reversed_text` which contains the character string `"Hello world!"` backwards as a `list` object.

# %%
reversed_text = list("Hello world!"[::-1])

# %% [markdown]
# ### 5. Create a variable `age`  and ask the user to enter his age. Then display it and display its type.

# %%
age = int(input("Please enter how old are you: "))
print(age, type(age), sep='\n')

# %% [markdown]
# ### 6. Create a variable `sorted_num` that contains the sorted `num` list.

# %%
num = [2, 8, 1, 4, 6, 3, 7]
sorted_num = sorted(num)

# %% [markdown]
# ### 7. Create a variable `sum_of_list` which contains the sum of all the elements in the list `num`.

# %%
num = [2, 8, 1, 4, 6, 3, 7]
sum_of_list = sum(num)

# %% [markdown]
# ### 8. Create a variable `min_value` that contains a minimum value of list `num`.

# %%
num = [2, 8, 1, 4, 6, 3, 7]
min_value = min(num)

# %% [markdown]
# ### 9. Create a variable `max_value` that contains the maximum value of list `num`.

# %%
num = [2, 8, 1, 4, 6, 3, 7]
max_value = max(num)

# %% [markdown]
# ### 10. Find a function that will interpret the string of the variable `calc`
# Save the result in a variable named `string_interpret`.

# %%
calc = "1 + 2"
string_interpret = eval(calc)

# %% [markdown]
# ## Testing
#
# The following piece of code is to test that you have correctly done the above exercises.
# If it fails, it means that some of your code is not correct. Read the error messages of each test carefully.
#
# If the syntax of the code below is confusing (`class`,`self`, etc...), don't worry, you will see it soon. The only thing you should know is that the method `assertEqual` checks if the right argument matches the left one, e.g. for `assertEqual(count_alpha, 12)` it checks that `count_alpha` is equal to 12.
#
# Please don't modify the code, you just have to execute it.

# %%
import unittest


class TestNotebook(unittest.TestCase):
    def test_count_alpha(self):
        self.assertEqual(count_alpha, 12)

    def test_count_float(self):
        self.assertEqual(type(count_float), float)

    def test_pi(self):
        self.assertEqual(3.14, round_pi)

    def test_reversed(self):
        self.assertEqual(
            reversed_text, ["!", "d", "l", "r", "o", "w", " ", "o", "l", "l", "e", "H"]
        )

    def test_age(self):
        self.assertEqual(type(age), str)

    def test_sorted(self):
        self.assertEqual(sorted_num, [1, 2, 3, 4, 6, 7, 8])

    def test_sum(self):
        self.assertEqual(sum_of_list, 31)

    def test_min(self):
        self.assertEqual(min_value, 1)

    def test_max(self):
        self.assertEqual(max_value, 8)

    def test_interpret(self):
        self.assertEqual(string_interpret, 3)


unittest.main(argv=[""], verbosity=2, exit=False)
# Out:
# test_age (__main__.TestNotebook.test_age) ... ERROR
# test_count_alpha (__main__.TestNotebook.test_count_alpha) ... ERROR
# test_count_float (__main__.TestNotebook.test_count_float) ... ERROR
# test_interpret (__main__.TestNotebook.test_interpret) ... ERROR
# test_max (__main__.TestNotebook.test_max) ... ERROR
# test_min (__main__.TestNotebook.test_min) ... ERROR
# test_pi (__main__.TestNotebook.test_pi) ... ERROR
# test_reversed (__main__.TestNotebook.test_reversed) ... ERROR
# test_sorted (__main__.TestNotebook.test_sorted) ... ERROR
# test_sum (__main__.TestNotebook.test_sum) ... ERROR
#
# ======================================================================
# ERROR: test_age (__main__.TestNotebook.test_age)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-2-ea26c17899a3>", line 20, in test_age
#     self.assertEqual(type(age), str)
#                           ^^^
# NameError: name 'age' is not defined
#
# ======================================================================
# ERROR: test_count_alpha (__main__.TestNotebook.test_count_alpha)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-2-ea26c17899a3>", line 6, in test_count_alpha
#     self.assertEqual(count_alpha, 12)
#                      ^^^^^^^^^^^
# NameError: name 'count_alpha' is not defined
#
# ======================================================================
# ERROR: test_count_float (__main__.TestNotebook.test_count_float)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-2-ea26c17899a3>", line 9, in test_count_float
#     self.assertEqual(type(count_float), float)
#                           ^^^^^^^^^^^
# NameError: name 'count_float' is not defined
#
# ======================================================================
# ERROR: test_interpret (__main__.TestNotebook.test_interpret)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-2-ea26c17899a3>", line 35, in test_interpret
#     self.assertEqual(string_interpret, 3)
#                      ^^^^^^^^^^^^^^^^
# NameError: name 'string_interpret' is not defined
#
# ======================================================================
# ERROR: test_max (__main__.TestNotebook.test_max)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-2-ea26c17899a3>", line 32, in test_max
#     self.assertEqual(max_value, 8)
#                      ^^^^^^^^^
# NameError: name 'max_value' is not defined
#
# ======================================================================
# ERROR: test_min (__main__.TestNotebook.test_min)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-2-ea26c17899a3>", line 29, in test_min
#     self.assertEqual(min_value, 1)
#                      ^^^^^^^^^
# NameError: name 'min_value' is not defined
#
# ======================================================================
# ERROR: test_pi (__main__.TestNotebook.test_pi)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-2-ea26c17899a3>", line 12, in test_pi
#     self.assertEqual(3.14, round_pi)
#                            ^^^^^^^^
# NameError: name 'round_pi' is not defined
#
# ======================================================================
# ERROR: test_reversed (__main__.TestNotebook.test_reversed)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-2-ea26c17899a3>", line 16, in test_reversed
#     reversed_text, ["!", "d", "l", "r", "o", "w", " ", "o", "l", "l", "e", "H"]
#     ^^^^^^^^^^^^^
# NameError: name 'reversed_text' is not defined
#
# ======================================================================
# ERROR: test_sorted (__main__.TestNotebook.test_sorted)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-2-ea26c17899a3>", line 23, in test_sorted
#     self.assertEqual(sorted_num, [1, 2, 3, 4, 6, 7, 8])
#                      ^^^^^^^^^^
# NameError: name 'sorted_num' is not defined
#
# ======================================================================
# ERROR: test_sum (__main__.TestNotebook.test_sum)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-2-ea26c17899a3>", line 26, in test_sum
#     self.assertEqual(sum_of_list, 31)
#                      ^^^^^^^^^^^
# NameError: name 'sum_of_list' is not defined
#
# ----------------------------------------------------------------------
# Ran 10 tests in 0.023s
#
# FAILED (errors=10)
